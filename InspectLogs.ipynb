# %%
# import tings

import pandas as pd
import numpy as np

# %%
eg_log = pd.read_csv('FlightLogs/Jan9.12-44.csv')

# %%
# get started combing through each log to get the aggregate data that actually matters
# start with {Jan9.12-44} as an example

# %%
eg_log.head()
# Out:
#    time(millisecond)            timestamp  altitude_above_seaLevel(feet)  \
# 0             422800  2026-01-09 12:44:32                      720.66432
# 1             422900  2026-01-09 12:44:32                      720.66432
# 2             423000  2026-01-09 12:44:32                      720.66432
# 3             423100  2026-01-09 12:44:32                      720.66432
# 4             423200  2026-01-09 12:44:32                      720.66432
#
#    height_sonar(feet)  speed(mph)  distance(feet)  mileage(feet)  satellites  \
# 0            0.328084         0.0        0.000000       0.000000          18
# 1            0.328084         0.0        0.009328       0.009328          18
# 2            0.328084         0.0        0.028029       0.028119          18
# 3            0.328084         0.0        0.042575       0.043574          18
# 4            0.328084         0.0        0.056100       0.059323          18
#
# ...
